# %%
import numpy as np

# %%
T = 11
es = 611.2 * np.exp(17.67 * T / (T + 243.5))
r = 5e-6
D = 2.2e-5
rho_l = 1e3
R_v = 461.5
print(0.5 * r ** 2 * (10 * rho_l * R_v * (T+273)) / (D * es))
# Out:
# 0.5676871806776307
